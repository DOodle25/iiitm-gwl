# %%
# 1. Data Inspection and Overview:
# df.head(n): Returns the first n rows (default 5) of the DataFrame, useful for a quick look at the data structure.
# df.tail(n): Returns the last n rows (default 5) of the DataFrame.
# df.info(): Provides a concise summary of the DataFrame, including data types, non-null values, and memory usage.
# df.shape: Returns a tuple representing the dimensions (rows, columns) of the DataFrame.
# df.columns: Returns an Index object containing the column labels of the DataFrame.
# df.dtypes: Returns a Series with the data type of each column.
# 2. Descriptive Statistics:
# df.describe(): Generates descriptive statistics for numerical columns, including count, mean, standard deviation, min, max, and quartiles.
# df.mean(), df.median(), df.mode(): Calculate the mean, median, and mode of numerical columns.
# df.min(), df.max(): Find the minimum and maximum values in numerical columns.
# df.std(), df.var(): Calculate the standard deviation and variance of numerical columns.
# df.value_counts(): Returns a Series containing counts of unique values in a column, useful for categorical data.
# df.corr(): Computes the pairwise correlation of columns.
# 3. Data Cleaning and Handling Missing Values:
# df.isnull(): / df.isna(): Returns a boolean DataFrame indicating missing values (True for NaN).
# df.notnull(): / df.notna(): Returns a boolean DataFrame indicating non-missing values.
# df.dropna(): Removes rows or columns containing missing values.
# df.fillna(value): Fills missing values with a specified value.
# 4. Data Selection and Filtering:
# df.loc[]: Label-based indexing for selecting rows and columns by their labels.
# df.iloc[]: Integer-location based indexing for selecting rows and columns by their integer positions.
# df[column_name]: Selects a single column.
# df[[column_name1, column_name2]]: Selects multiple columns.
# df[df['column'] > value]: Filters rows based on a condition.
# 5. Data Manipulation:
# df.sort_values(by='column_name', ascending=True): Sorts the DataFrame by one or more columns.
# df.groupby('column_name'): Groups the DataFrame by a column for aggregation.
# df.apply(function): Applies a function along an axis of the DataFrame.
# df.merge(), pd.concat(): Functions for combining DataFrames.
