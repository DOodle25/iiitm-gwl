# %% [markdown]
# # Missing Values Cheatsheet
#
# Techniques for handling missing values in pandas DataFrames.

# %%
# Load data
import pandas as pd
df = pd.read_csv('./titanic/train.csv')
print('Data loaded')
# Out:
# Data loaded

# %%
# Check for missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Drop rows with missing values
df_dropped = df.dropna()
print(df_dropped.shape)
# Out:
# (183, 12)

# %%
# Drop columns with missing values
df_dropped_col = df.dropna(axis=1)
print(df_dropped_col.shape)
# Out:
# (891, 9)

# %%
# Fill missing values with a specific value
df_filled = df.fillna(0)
print(df_filled.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Fill missing values with mean
df['Age'].fillna(df['Age'].mean(), inplace=True)
print(df['Age'].isnull().sum())
# Out:
# 0
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_4484\1681058792.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
# Fill missing values with median
df['Fare'].fillna(df['Fare'].median(), inplace=True)
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_4484\2954369549.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(df['Fare'].median(), inplace=True)

# %%
# Fill missing values with mode
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_4484\234985386.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
# Forward fill
df_ffill = df.fillna(method='ffill')
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_4484\2861128085.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method='ffill')

# %%
# Backward fill
df_bfill = df.fillna(method='bfill')
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_4484\671895346.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method='bfill')

# %%
# Interpolate
df_interp = df.interpolate()
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_4484\2430014960.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_interp = df.interpolate()
